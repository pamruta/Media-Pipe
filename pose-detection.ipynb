# %%
# !pip install mediapipe==0.10.14

# %%
import cv2

# %%
# import mediapipe library

import mediapipe as mp
mp_pose = mp.solutions.pose
mp_draw = mp.solutions.drawing_utils

# %%
# load sample image
from google.colab.patches import cv2_imshow
image_file = "sample.jpg"
image = cv2.imread(image_file)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x710>

# %%
# convert to RGB
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# run pose detection
pose = mp_pose.Pose()
output = pose.process(rgb_image)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# display pose landmark points
if output.pose_landmarks:
  mp_draw.draw_landmarks(image, output.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                        landmark_drawing_spec = mp_draw.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
                        connection_drawing_spec = mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2))
  cv2_imshow(image)
else:
  print("Couldn't detect any human body..")
# Out:
# <PIL.Image.Image image mode=RGB size=1000x710>

# %%
# get specific landmark point
print(output.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE])
# Out:
# x: 0.491509587
# y: 0.468399048
# z: 0.125976115
# visibility: 0.347187489
