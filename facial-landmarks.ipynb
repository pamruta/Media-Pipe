# %%
# !pip install mediapipe==0.10.14

# %%
import cv2

# %%
# import mediapipe library

import mediapipe as mp
mp_facemesh = mp.solutions.face_mesh
mp_draw = mp.solutions.drawing_utils

# %%
# load sample image
from google.colab.patches import cv2_imshow
image_file = "sample.jpg"
image = cv2.imread(image_file)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=440x580>

# %%
# convert to RGB
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# run face mesh model
face = mp_facemesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True)
output = face.process(rgb_image)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# display facial landmark points
if output.multi_face_landmarks:
  for landmarks in output.multi_face_landmarks:
    mp_draw.draw_landmarks(image, landmarks, mp_facemesh.FACEMESH_TESSELATION,
                          landmark_drawing_spec = mp_draw.DrawingSpec(color=(255, 255, 255), thickness=2, circle_radius=1),
                          connection_drawing_spec = mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2))
    cv2_imshow(image)
else:
  print("Couldn't detect any face..")
# Out:
# <PIL.Image.Image image mode=RGB size=440x580>

# %%
print(output.multi_face_landmarks)
